# %% [markdown]
# ## 🧭 About This Notebook
#
# This is the **primary analysis notebook** for the project — the production pipeline in `src/` (`ingestion.py` → `preprocessing.py` → `features.py` → `train.py` → `predict.py`) is built from the approach worked out here.
#
# Every code cell below now has a short markdown explanation directly above it describing *what* the cell does and *why*. The original "Takeaway" markdown cells are left untouched — they capture the *conclusion* drawn from each result, while the new cells explain the *mechanics*.
#
# First, import the libraries used throughout: `numpy`/`pandas` for data handling and math, `sklearn` for the modeling utilities (train/test split, Logistic Regression, metrics) used later on.
#
# See also [`docs/CONCEPTS.md`](../docs/CONCEPTS.md) and [`docs/ARCHITECTURE.md`](../docs/ARCHITECTURE.md) for a deeper reference built from this same analysis.

# %%
import numpy as np
import pandas as pd
import sklearn

# %% [markdown]
# Load the raw sensor readings into a DataFrame and preview the first 5 rows with `.head()` — a quick sanity check that column names, data types, and value ranges all look plausible before doing any real analysis.

# %%
df = pd.read_csv("aircompressor.csv")
df.head()
# Out:
#    id  rpm  motor_power     torque  outlet_pressure_bar    air_flow  \
# 0   1  499  1405.842858  27.511708                1.000  308.289879
# 1   2  513  1457.370092  31.030115                1.081  307.833736
# 2   3  495  1582.249959  33.484653                1.369  307.377593
# 3   4  480  1712.466820  36.394475                1.691  306.975248
# 4   5  498  1766.035170  38.249154                1.731  306.832132
#
#     noise_db  outlet_temp  wpump_outlet_press  water_inlet_temp  ...  \
# 0  40.840517    78.554715            2.960632         43.166392  ...
# 1  40.484226    76.902822            2.536711         47.342143  ...
# 2  40.918572    77.547021            2.112789         49.306593  ...
# 3  40.450953    80.059949            2.087534         46.886933  ...
# 4  41.233739    79.130424            2.338877         50.498100  ...
#
#       gaccy     gaccz     haccx     haccy     haccz  bearings  wpump  \
# ...

# %% [markdown]
# Check the overall size of the dataset — how many sensor readings (rows) and how many columns (features + targets) are available. This tells us up front how much data there is to work with (and confirms the 1000-row, 26-column shape mentioned in the project README).

# %%
# total number of rows and columns
df.shape    # 1000 records, 26 features
# Out:
# (1000, 26)

# %% [markdown]
# `df.count()` reports the number of **non-null** values per column. Comparing this against the total row count (1000) is a first, quick way to spot missing data — if any column reports fewer than 1000, it has gaps that will need handling.

# %%
# count of non null values
df.count()
# Out:
# id                     1000
# rpm                    1000
# motor_power            1000
# torque                 1000
# outlet_pressure_bar    1000
# air_flow               1000
# noise_db               1000
# outlet_temp            1000
# wpump_outlet_press     1000
# water_inlet_temp       1000
# water_outlet_temp      1000
# wpump_power            1000
# water_flow             1000
# oilpump_power          1000
# oil_tank_temp          1000
# gaccx                  1000
# gaccy                  1000
# gaccz                  1000
# haccx                  1000
# haccy                  1000
# haccz                  1000
# bearings               1000
# wpump                  1000
# radiator               1000
# exvalve                1000
# acmotor                1000
# dtype: int64

# %% [markdown]
# `df.isna().sum()` is the complementary check — it directly counts **missing** values per column instead of non-null ones. Together with the previous cell this confirms whether the dataset needs any imputation before modeling (here, it doesn't — every column is fully populated).

# %%
# count of null values
df.isna().sum()
# Out:
# id                     0
# rpm                    0
# motor_power            0
# torque                 0
# outlet_pressure_bar    0
# air_flow               0
# noise_db               0
# outlet_temp            0
# wpump_outlet_press     0
# water_inlet_temp       0
# water_outlet_temp      0
# wpump_power            0
# water_flow             0
# oilpump_power          0
# oil_tank_temp          0
# gaccx                  0
# gaccy                  0
# gaccz                  0
# haccx                  0
# haccy                  0
# haccz                  0
# bearings               0
# wpump                  0
# radiator               0
# exvalve                0
# acmotor                0
# dtype: int64

# %% [markdown]
# Check how imbalanced the target is: what percentage of rows have `bearings == 0` (healthy) vs. `bearings == 1` (faulty)? This matters because a heavily imbalanced target (as we'll see, 80/20) changes how models should be evaluated — plain accuracy becomes misleading, which is why later cells use precision/recall/F1 instead.

# %%
# count of each bearings status as percentage
df['bearings'].value_counts(normalize=True) * 100
# Out:
# bearings
# 0    80.0
# 1    20.0
# Name: proportion, dtype: float64

# %% [markdown]
# Split the dataset into two subsets based on the `bearings` label: `healthy_df` (bearings OK) and `faulty_df` (bearings faulty). Comparing sensor statistics *between* these two groups (next cells) is a simple but effective way to discover which sensors actually shift when a component is failing, before building any model.

# %%
# Separate healthy and faulty data
healthy_df = df[df['bearings'] == 0]
faulty_df  = df[df['bearings'] == 1]

# %% [markdown]
# Compare summary statistics (`count`, `mean`, `std`, `min/25/50/75/max`) for every sensor, computed separately on the healthy subset and then the faulty subset (next cell). Sensors whose **mean** differs noticeably between the two `.describe()` tables are candidates for predictive features; sensors that look nearly identical in both are probably not useful for detecting bearing problems.

# %%
healthy_df.describe()
# Out:
#                 id          rpm   motor_power      torque  \
# count   800.000000   800.000000    800.000000  800.000000
# mean    510.500000  1499.476250   6958.695695   48.928602
# std     289.375055   707.853044   4239.238109   18.286715
# min       1.000000   480.000000   1403.720659   13.222197
# 25%     270.750000   988.750000   3559.437042   33.773217
# 50%     520.500000  1500.000000   5874.425203   48.555078
# 75%     760.250000  2009.250000   9683.007776   63.292138
# max    1000.000000  2520.000000  19454.559080   93.540405
#
#        outlet_pressure_bar     air_flow    noise_db  outlet_temp  \
# count           800.000000   800.000000  800.000000   800.000000
# mean              4.027931   717.188470   52.006550   120.245751
# std               1.821015   438.814968    7.275859    19.361857
# min               1.000000    95.098952   39.879017    76.902822
# 25%               2.450000   302.307224   45.673130   106.091497
# ...

# %%
faulty_df.describe()
# Out:
#               id          rpm   motor_power      torque  outlet_pressure_bar  \
# count  200.00000   200.000000    200.000000  200.000000           200.000000
# mean   460.50000  1499.675000   7089.604074   50.216193             4.158520
# std    283.78853   708.771972   4396.676262   20.316411             2.022635
# min     41.00000   480.000000   1402.424603   13.368173             1.000000
# 25%    250.75000   989.250000   3567.173049   33.729909             2.412500
# 50%    460.50000  1499.500000   6138.073322   50.168882             4.096000
# 75%    670.25000  2010.250000   9405.337057   65.942909             5.772250
# max    880.00000  2519.000000  18127.866090   90.700542             8.664000
#
#           air_flow    noise_db  outlet_temp  wpump_outlet_press  \
# count   200.000000  200.000000   200.000000          200.000000
# mean    904.615770   59.034408   113.292547            2.719087
# std     427.396203    8.572453    17.064747            0.460346
# ...

# %% [markdown]
# Compute the average `noise_db` for each bearing status with `.groupby("bearings").mean()`, then visualize the full distribution (not just the mean) with a boxplot split by `bearings` — boxplots make it easy to see if the two groups' noise levels actually separate, or just overlap with different averages.

# %%
# Is the noise higher when bearings are bad?
# Compare average noise by bearings
print(df.groupby("bearings")["noise_db"].mean())
df.boxplot(column='noise_db', by='bearings')
# Out:
# bearings
# 0    52.006550
# 1    59.034408
# Name: noise_db, dtype: float64
# <Axes: title={'center': 'noise_db'}, xlabel='bearings'>

# %% [markdown]
# Takeaway - When bearings are faulty, the noise level is generally higher.

# %% [markdown]
# Repeat the same groupby-mean-and-boxplot pattern as the noise check above, but for `oil_tank_temp` instead — testing the hypothesis that a bearing running hotter (due to more friction) shows up as a hotter oil reservoir.

# %%
# Check temperature vs bearing condition
# bearings rely on lubrication
# Bad bearings - more friction - oil heats up
print(df.groupby('bearings')['oil_tank_temp'].mean())
df.boxplot(column='oil_tank_temp', by='bearings')
# Out:
# bearings
# 0    46.251167
# 1    46.183647
# Name: oil_tank_temp, dtype: float64
# <Axes: title={'center': 'oil_tank_temp'}, xlabel='bearings'>

# %% [markdown]
# Takeaway - Oil Tank Temp is NOT a good indicator of bearing problems in this dataset.

# %% [markdown]
# Check Vibration magnitude
#
# - Ground Acceleration (X, Y, Z)
# - Head Acceleration (X, Y, Z)

# %% [markdown]
# Combine the three ground-acceleration axes (`gaccx`, `gaccy`, `gaccz`) into a single vibration-intensity number using the **vector magnitude (Euclidean norm)**:
#
# $$
# \text{ground\_acc\_mag} = \sqrt{\text{gaccx}^2 + \text{gaccy}^2 + \text{gaccz}^2}
# $$
#
# This captures overall vibration strength regardless of which direction it's occurring in, collapsing 3 correlated columns into 1 more interpretable feature (see [`docs/ARCHITECTURE.md` §3.5](../docs/ARCHITECTURE.md) for why the 3 axes are so highly correlated in this dataset).

# %%
df['ground_acc_mag'] = np.sqrt(
    df['gaccx']**2 +
    df['gaccy']**2 +
    df['gaccz']**2
)

# %% [markdown]
# Same groupby-mean pattern as before, now applied to the new `ground_acc_mag` feature — checking whether overall vibration intensity is actually higher when bearings are faulty.

# %%
df.groupby('bearings')['ground_acc_mag'].mean()
# Out:
# bearings
# 0    3.957795
# 1    4.139234
# Name: ground_acc_mag, dtype: float64

# %% [markdown]
# Takeaway - Vibration is higher when bearings are faulty

# %% [markdown]
# Same groupby-mean pattern once more, applied to `motor_power` — testing whether a struggling/faulty bearing makes the motor draw more power to maintain the same speed (more friction to overcome).

# %%
# Does power increase when bearings are bad?
# Bad bearings → more friction → motor works harder
df.groupby('bearings')['motor_power'].mean()
# Out:
# bearings
# 0    6958.695695
# 1    7089.604074
# Name: motor_power, dtype: float64

# %% [markdown]
# Takeaway - Motor power is higher when bearings are faulty

# %% [markdown]
# | Signal                 | When bearings are bad |
# | ---------------------- | --------------------- |
# | Noise dB               | Increases             |
# | Vibration (ground acc) | Increases             |
# | Motor Power            | Increases             |

# %% [markdown]
# Having found that `noise_db`, `ground_acc_mag`, and `motor_power` all separate meaningfully between healthy and faulty bearings (per the table above), select exactly those three as the model's input features (`X`) and use the original `bearings` column as the target (`y`) — this is a diagnostic model: "is this bearing faulty *right now*?"

# %%
features = [
    'noise_db',
    'ground_acc_mag',
    'motor_power'
]

X = df[features]
y = df['bearings']

# %% [markdown]
# Split the data into training and test sets. Note `shuffle=False`: because these rows are a time-ordered sensor stream, shuffling before splitting would let the model train on data from *after* the test period — a form of data leakage. Keeping the original order and taking the last 20% as test data gives a more honest read of how the model performs on unseen future readings.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=False
)

# %% [markdown]
# Fit a **Logistic Regression** classifier — a linear model that estimates $P(y=1\mid x) = \sigma(w^\top x + b) = \frac{1}{1+e^{-(w^\top x+b)}}$ — on the training features and labels. It's used here as a simple, fast, interpretable baseline before trying anything more complex.

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Generate predictions on the held-out test set and print a `classification_report`, which shows **precision**, **recall**, and **F1-score** per class plus overall accuracy. This is far more informative than accuracy alone for an imbalanced target like this one — it shows explicitly how well the model catches faulty bearings (class 1) specifically, not just how often it's right overall.

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83       160
#            1       0.46      1.00      0.63        40
#
#     accuracy                           0.77       200
#    macro avg       0.73      0.85      0.73       200
# weighted avg       0.89      0.77      0.79       200

# %% [markdown]
# Bearings don’t fail suddenly.
# They show warning signs before failure.
#
# So we will:
#
# - Take data before a failure
#
# - Label it as “failure coming”

# %% [markdown]
# Mark a row as 1 if a bearing failure will happen in the next 5 rows

# %% [markdown]
# Turn the diagnostic label into a **predictive** one. For fault indicator $f_t$ and a 5-row horizon: `rolling(window=5).max()` computes the *trailing* max $\max(f_{t-4}, \dots, f_t)$ — whether a failure occurred anywhere in the past 5 rows — and `.shift(-5)` then pulls that value 5 steps **backward** in time, turning it into a *leading* indicator. The net effect: row $t$ gets labeled `1` if a failure occurs anywhere in the *next* 5 rows, i.e. $y_t = \max(f_{t+1}, \dots, f_{t+5})$.

# %%
df['bearing_failure_soon'] = (
    df['bearings']
    .rolling(window=5)
    .max()
    .shift(-5)
)

# %% [markdown]
# The `rolling().shift()` combination above leaves `NaN` labels for the last 5 rows of the dataset (there's no full future window to look at near the end of the series). `dropna()` removes those trailing rows so every remaining row has a valid `bearing_failure_soon` label.

# %%
df = df.dropna()

# %% [markdown]
# Check the class balance of the new predictive label the same way the original `bearings` balance was checked earlier — confirming the label still has a reasonable (if imbalanced) mix of both classes after the rolling/shift/dropna transformation.

# %%
df['bearing_failure_soon'].value_counts()
# Out:
# bearing_failure_soon
# 0.0    775
# 1.0    220
# Name: count, dtype: int64

# %% [markdown]
# Predictive labels look different from diagnostic labels

# %% [markdown]
# Rebuild the feature matrix `X` using the same three engineered features as before (`noise_db`, `ground_acc_mag`, `motor_power`), but this time point the target `y` at the new **predictive** label, `bearing_failure_soon`, instead of the original diagnostic `bearings` column.

# %%
features = [
    'noise_db',
    'ground_acc_mag',
    'motor_power'
]

X = df[features]
y = df['bearing_failure_soon']

# %% [markdown]
# Split into train/test again with the same `shuffle=False`, time-preserving approach as before — now on the predictive-label dataset — so the upcoming evaluation reflects genuine forecasting performance, not shuffled/leaked data.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=False
)

# %% [markdown]
# Evaluate how well the **existing** `model` (still the Logistic Regression fit earlier on the *diagnostic* `bearings` target) performs when asked to predict the new *predictive* `bearing_failure_soon` target — note this cell does **not** refit the model on `y_train`; it directly reuses the previously-learned decision boundary. This tests whether the sensor pattern the model learned for "bearing is faulty now" also happens to show up a few rows *before* the failure, since the rolling/shift construction means the two labels overlap for several rows around each failure event.

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.69      0.80       155
#          1.0       0.45      0.89      0.60        44
#
#     accuracy                           0.73       199
#    macro avg       0.70      0.79      0.70       199
# weighted avg       0.84      0.73      0.76       199

# %% [markdown]
# `Class 1 (failure soon)`
#
# `Recall  = 0.89`
#
# The model catches ~89% of upcoming bearing failures

# %% [markdown]
# Why precision for class 1 is still low (0.45)?
#
# About half of the warnings are early or cautious.

# %% [markdown]
# ## FFT (Fast Fourier Transform) Application
#
# blog link - https://f7i.ai/blog/beyond-the-squiggly-lines-the-ultimate-2025-guide-to-fft-analysis-for-maintenance-professionals
#
# Why Fourier Transform in predictive maintenance?
#
# Bearings don't just increase vibration, They vibrate at specific frequencies when damaged.
#
# FFT helps answer: What frequencies are present in the vibration?

# %% [markdown]
# Next Steps :
#
# - Take vibration magnitude
#
# - Apply FFT
#
# - Extract ONE simple frequency feature
#
# - Add it to the model

# %% [markdown]
# What FFT gives you?
#
# FFT converts Time signal to Frequency signal
#
# Example:
#
# - Time domain: vibration goes up and down
# - Frequency domain : shows how fast it oscillates
#
# Bad bearings usually show:
# - Higher high-frequency energy

# %% [markdown]
# Apply FFT to the vibration signal

# %% [markdown]
# Compute the **Discrete Fourier Transform** of the vibration signal with `np.fft.fft`, converting it from the time domain (value vs. time) into the frequency domain:
#
# $$
# X_k = \sum_{n=0}^{N-1} x_n\, e^{-i2\pi kn/N}
# $$
#
# `np.abs(...)` then converts each complex coefficient into a magnitude, giving the **amplitude spectrum** — how strongly each frequency is present in the signal.

# %%
fft_vals = np.fft.fft(df['ground_acc_mag'].values)
fft_vals = np.abs(fft_vals)

# %% [markdown]
# Use only half the spectrum, FFT output is symmetric.

# %% [markdown]
# For a real-valued input signal (as all sensor readings are), the FFT output is mirror-symmetric ($|X_{N-k}| = |X_k|$), so the second half of `fft_vals` is redundant. Keep only the first half.

# %%
fft_vals = fft_vals[:len(fft_vals)//2]

# %% [markdown]
# Create one FFT-based feature
#
# We'll create High-Frequency Energy

# %% [markdown]
# Compute a single scalar feature from the spectrum: the average amplitude across the **upper half** of the frequency bins,
#
# $$
# E_{\text{high}} = \text{mean}\big(|X_k| : k \ge N/2\big)
# $$
#
# The hypothesis being tested: damaged bearings push more vibration energy into higher frequencies than smooth, healthy rotation.

# %%
# Define frequency split
high_freq_energy = np.mean(fft_vals[int(len(fft_vals)*0.5):])

# %% [markdown]
# This roughly means:
# - Look at the upper half of frequencies
# - Average their energy

# %% [markdown]
# Store the high-frequency energy value computed above as a new column. ⚠️ As written, `high_freq_energy` is a single number computed once from the **entire** signal, so every row of `df['fft_high_freq_energy']` gets exactly the same value — this is the "global FFT" mistake the notebook diagnoses and fixes a few cells down.

# %%
# Add it as a feature
df['fft_high_freq_energy'] = high_freq_energy

# %% [markdown]
# Sanity-check the new feature by comparing its average between the two `bearing_failure_soon` classes. Because the feature is a single constant value repeated for every row (see the note above), this comparison will show **no difference at all** between the classes — confirming the feature is currently useless, which motivates the windowed-FFT fix below.

# %%
# check if feature makes sense
df.groupby('bearing_failure_soon')['fft_high_freq_energy'].mean()
# Out:
# bearing_failure_soon
# 0.0    7.479577
# 1.0    7.479577
# Name: fft_high_freq_energy, dtype: float64

# %% [markdown]
# ## PdM LESSON (Remember this)
#
# FFT must be computed on small time windows, not on the full signal.
#
# Bearings degrade locally in time, not globally.

# %% [markdown]
# Let's do WINDOWED FFT
#
# - Take small chunks of vibration
# - Compute FFT per chunk
# - Assign result to the last row of the chunk
#
# choose window size - 20 rows
#
# meaning: Look at vibration behavior over 20 time steps

# %% [markdown]
# Fix the "global FFT" problem with a **sliding window**: for each row `i`, take the trailing 20 samples of the vibration signal, compute their FFT and amplitude spectrum, keep only the first half (Nyquist), and average the upper half to get a high-frequency-energy value *local to that window* — assigning it to the *last* row of the window. This mirrors the rolling-window pattern used for `ground_acc_mag` earlier, just with an FFT instead of a mean, and is the key fix: bearing degradation is a local-in-time phenomenon, so the feature needs to be recomputed on recent history, not the whole signal at once.

# %%
# Loop over windows
window_size = 20

signal = df['ground_acc_mag'].values

for i in range(window_size, len(signal)):
    window = signal[i-window_size:i]

    fft_vals = np.abs(np.fft.fft(window))
    fft_vals = fft_vals[:len(fft_vals)//2]

    high_freq_energy = np.mean(fft_vals[len(fft_vals)//2:])

    df.loc[df.index[i], 'fft_high_freq_energy'] = high_freq_energy

# %% [markdown]
# The windowed loop above only starts writing values once there are `window_size` (20) prior rows to look back on, so the first 20 rows are left with `NaN` in `fft_high_freq_energy`. Drop those rows before using the feature.

# %%
# Remove rows without FFT values
df = df.dropna(subset=['fft_high_freq_energy'])

# %% [markdown]
# Re-run the same groupby-mean check as before, now on the properly **windowed** FFT feature — this time the values differ meaningfully between classes, confirming the windowed version actually carries signal that the single-global-value version didn't.

# %%
# Check if windowed FFT now makes sense
df.groupby('bearing_failure_soon')['fft_high_freq_energy'].mean()
# Out:
# bearing_failure_soon
# 0.0    2.485958
# 1.0    2.221819
# Name: fft_high_freq_energy, dtype: float64

# %% [markdown]
# Why did you use FFT?
#
# I compute FFT-based energy features on sliding windows of vibration magnitude to capture localized frequency-domain changes caused by bearing degradation.

# %% [markdown]
# What windowed FFT result is telling us?
#
# High-frequency energy is slightly lower before failure.

# %% [markdown]
# ## Important PdM lesson
#
# Not every FFT feature increases before failure

# %% [markdown]
# ### Spectral spread

# %% [markdown]
# Engineer a second FFT-based feature: **spectral spread**, the standard deviation of the amplitude spectrum within each 20-row window,
#
# $$
# \sigma_{\text{spread}} = \sqrt{\tfrac{1}{N/2}\sum_{k=0}^{N/2-1}\big(|X_k| - \overline{|X|}\big)^2}
# $$
#
# This measures how *dispersed* vibration energy is across frequencies (a wide, noisy spectrum vs. one concentrated at a single peak), using the same sliding-window mechanics as the high-frequency-energy feature above.

# %%
# Create a new FFT feature
df['fft_spectral_spread'] = np.nan

for i in range(window_size, len(signal)):
    window = signal[i-window_size:i]

    fft_vals = np.abs(np.fft.fft(window))
    fft_vals = fft_vals[:len(fft_vals)//2]

    spread = np.std(fft_vals)

    df.loc[df.index[i], 'fft_spectral_spread'] = spread

# %% [markdown]
# As with the high-frequency-energy feature, the first `window_size` rows have no `fft_spectral_spread` value yet — drop them before analyzing the feature.

# %%
# drop NaNs
df = df.dropna(subset=['fft_spectral_spread'])

# %% [markdown]
# Check whether `fft_spectral_spread` differs between the two classes, the same way every other engineered feature has been validated so far in this notebook.

# %%
df.groupby('bearing_failure_soon')['fft_spectral_spread'].mean()
# Out:
# bearing_failure_soon
# 0.0    22.843158
# 1.0    23.050434
# Name: fft_spectral_spread, dtype: float64

# %% [markdown]
# Not all FFT energy features increase before failure. In my dataset, early bearing degradation caused energy concentration rather than broadband noise, so I used spectral spread to capture this effect.

# %% [markdown]
# (Re-displaying the same group means as the cell above, just before drawing the conclusion below — no new computation here.)

# %%
df.groupby('bearing_failure_soon')['fft_spectral_spread'].mean()
# Out:
# bearing_failure_soon
# 0.0    22.843158
# 1.0    23.050434
# Name: fft_spectral_spread, dtype: float64

# %% [markdown]
# Spectral spread is slightly higher before failure.
#
# This tells us:
#
# - The vibration spectrum becomes less stable
#
# - Energy spreads irregularly across frequencies
#
# - This is a classic early degradation signal

# %% [markdown]
# ## Important PdM lesson (remember this)
#
# Early failure signals are subtle, not dramatic
#
# If the difference were huge:
#
# - The bearing would already be failing
# - Predictive value would be low

# %% [markdown]
# Next Steps
#
# - Add this FFT feature to the predictive model
# - See if it helps early warning
# - Interpret the outcome

# %% [markdown]
# Assemble the final feature set for the improved model: the original three sensor-derived features plus the new `fft_spectral_spread` feature, still predicting the forward-looking `bearing_failure_soon` label.

# %%
# Add FFT feature to predictive model
features = [
    'noise_db',
    'ground_acc_mag',
    'motor_power',
    'fft_spectral_spread'
]

X = df[features]
y = df['bearing_failure_soon']

# %% [markdown]
# Split into train/test one more time, same `shuffle=False` time-preserving approach as every previous split in this notebook, now on the FFT-augmented feature set.

# %%
# Train / test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    shuffle=False
)

# %% [markdown]
# Fit a **fresh** Logistic Regression model — this time properly retrained on the FFT-augmented training data (unlike the earlier reused-model comparison). `max_iter=1000` raises the solver's default iteration cap so it has enough iterations to converge with the extra feature added.

# %%
# train model
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Evaluate the FFT-augmented model the same way as the very first model — via `classification_report` — so its precision/recall/F1 can be directly compared against the pre-FFT baseline (see the comparison markdown below).

# %%
# Evaluate
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.70      0.80       151
#          1.0       0.46      0.89      0.60        44
#
#     accuracy                           0.74       195
#    macro avg       0.71      0.79      0.70       195
# weighted avg       0.84      0.74      0.76       195

# %% [markdown]
# ### Compare Models (with and without FFT)
#
# - Before FFT
#     - Failure recall ~ 0.89
#     - Accuracy ~ 0.73
#
# - After adding FFT spectral spread
#     - Failure recall ~ 0.89
#     - Accuracy ~ 0.74
#
# Very small change
#
# What this means - FFT did not dramatically improve performance.
#
# Why?
#
# - Your original signals (noise, vibration magnitude, power) are already strong
#
# - FFT adds secondary information
#
# - With only 1000 rows, gains will be subtle
#
# This is extremely common in real PdM projects.
#
# This is actually a GOOD sign
#
# Bad sign ❌:
#
# - FFT suddenly boosts accuracy by 15%
# (generally means data leakage or overfitting)
#
# Good sign ✅:
#
# - Small, stable improvement
#
# - Failure recall remains high
#
# - Model behavior stays consistent
#
# ### IMPORTANT PdM LESSON
#
# FFT is not magic — it refines, not replaces, time-domain features

# %% [markdown]
# Create FFT Plot for ground_acc_mag

# %% [markdown]
# Pull out two raw vibration segments for plotting: the first 256 `ground_acc_mag` readings where `bearing_failure_soon == 0` (normal operation) and the first 256 where it's `1` (failure approaching). ⚠️ Note `window_size` is reassigned to `256` here, reusing the same variable name as the `window_size = 20` used for the sliding-FFT feature loops above — harmless since those loops have already finished running, but worth noticing if you re-run cells out of order.

# %%
window_size = 256

normal_signal = df[df['bearing_failure_soon'] == 0]['ground_acc_mag'].values[:window_size]
fault_signal  = df[df['bearing_failure_soon'] == 1]['ground_acc_mag'].values[:window_size]

# %% [markdown]
# Compute the FFT of each 256-sample segment independently — one full spectrum for "normal" behavior, one for "failure soon" behavior — so their frequency content can be compared directly.

# %%
fft_normal = np.fft.fft(normal_signal)
fft_fault  = np.fft.fft(fault_signal)

# %% [markdown]
# Convert both complex FFT outputs into amplitude spectra with `np.abs`, exactly as in the single-feature computation earlier.

# %%
fft_normal_mag = np.abs(fft_normal)
fft_fault_mag  = np.abs(fft_fault)

# %% [markdown]
# Convert FFT bin *indices* into actual frequencies in Hz using $f_k = \dfrac{k \cdot f_s}{N}$, assuming a sampling rate of `fs = 1000` Hz — needed only to label the x-axis of the plot below in physically meaningful units rather than raw bin numbers.

# %%
fs = 1000  # Hz (assumed)
freqs = np.fft.fftfreq(window_size, d=1/fs)

# %% [markdown]
# Keep only the first half of each spectrum (the Nyquist limit for a real-valued signal, same reasoning as earlier in the notebook) for both the frequency axis and the two amplitude spectra, so the upcoming plot doesn't show the redundant mirrored half.

# %%
half = window_size // 2

freqs = freqs[:half]
fft_normal_mag = fft_normal_mag[:half]
fft_fault_mag = fft_fault_mag[:half]

# %% [markdown]
# Plot amplitude vs. frequency for the normal and failure-soon segments on the same axes. This is the visual counterpart of the `fft_spectral_spread`/high-frequency-energy features computed earlier — it lets you *see* whether the failure-soon spectrum looks wider/noisier or has different peak frequencies compared to normal operation.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(freqs, fft_normal_mag, label='Normal Bearings')
plt.plot(freqs, fft_fault_mag, label='Failure Soon')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('FFT of Ground Acceleration')
plt.legend()
plt.show()

# %% [markdown]
# What does this FFT plot shows?
#
# Compared to normal operation, bearings approaching failure show a slightly wider and noisier frequency spectrum, indicating increased vibration instability rather than a dominant fault frequency.
